# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.config import PROCESSED_DATA_DIR
from src.feature_selection.embedded import LASSO, MDI

import numpy as np
import pandas as pd

from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(PROCESSED_DATA_DIR / "dataset.csv").drop(columns=(["NDVI", "NDVI_binary", "NO2_column_number_density"]))
df.head()
# Out:
#    COUNTYFP  year  surface_latent_heat_flux_sum  \
# 0         3  2016                 -2.025289e+09
# 1         3  2017                 -2.048438e+09
# 2         3  2018                 -2.010754e+09
# 3         3  2019                 -1.943294e+09
# 4         3  2020                 -2.006264e+09
#
#    surface_net_solar_radiation_sum  surface_solar_radiation_downwards_sum  \
# 0                     4.313320e+09                           5.391195e+09
# 1                     4.247273e+09                           5.288023e+09
# 2                     4.050662e+09                           5.168220e+09
# 3                     4.079229e+09                           5.159034e+09
# 4                     4.246006e+09                           5.318185e+09
#
#    surface_thermal_radiation_downwards_sum  evaporation_from_bare_soil_sum  \
# 0                             1.006522e+10                       -0.569907
# 1                             1.002664e+10                       -0.575449
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df, df["depr_prev"], test_size=0.2)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.drop(columns=["depr_prev"]))
X_test_scaled = scaler.transform(X_test.drop(columns=["depr_prev"]))

# %%
lasso = LassoCV(cv=5, random_state=42, max_iter=100_000)
lasso.fit(X_train_scaled, y_train)
# Out:
# LassoCV(cv=5, max_iter=100000, random_state=42)

# %%
lasso.coef_
# Out:
# array([ 3.91712864e-05, -7.96661863e-04, -0.00000000e+00, -2.25431196e-03,
#         8.24681181e-04,  3.20414508e-03,  6.52952029e-03,  9.14985349e-03,
#         2.63569055e-04, -1.00231332e-02, -1.72551762e-03,  4.18685050e-04,
#        -4.84762273e-04, -1.91815137e-03,  4.54156386e-04, -1.60749507e-03,
#        -4.96607848e-04,  0.00000000e+00, -3.87321417e-03, -2.14784492e-03,
#         2.98135863e-04, -6.96570898e-03,  4.11543678e-03, -1.57593720e-04,
#        -3.29831220e-03,  0.00000000e+00,  2.58642154e-03,  8.00065450e-03,
#        -9.90919678e-04, -2.51894186e-03,  8.80375380e-04, -2.54700580e-04,
#         0.00000000e+00, -0.00000000e+00, -8.16640908e-03, -2.03531713e-03,
#        -3.67249673e-04,  0.00000000e+00,  1.29599144e-02,  0.00000000e+00,
#        -5.37179867e-03,  3.13146838e-03, -1.68364844e-02,  0.00000000e+00,
#        -1.06836511e-03,  4.43127355e-03, -1.14819046e-02,  6.94495300e-03,
# ...

# %%
lasso.alpha_
# Out:
# np.float64(8.621804834634574e-06)

# %%
LASSO(df, alpha=0.00082)
# Out:
# Index(['year', 'surface_thermal_radiation_downwards_sum', 'snow_depth',
#        'volumetric_soil_water_layer_3', 'leaf_area_index_high_vegetation',
#        'leaf_area_index_low_vegetation', 'bare-coverfraction',
#        'grass-coverfraction', 'water-seasonal-coverfraction',
#        'Education_LT12years_score'],
#       dtype='object')

# %%
MDI(df, top_k=10)
# Out:
# Index(['year', 'soil_temperature_level_1', 'crops-coverfraction',
#        'grass-coverfraction', 'snow_depth', 'urban-coverfraction',
#        'total_aerosol_optical_depth_at_550nm_surface',
#        'soil_temperature_level_3', 'surface_pressure', 'snow_cover'],
#       dtype='object')
