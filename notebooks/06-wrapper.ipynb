# %%
from src.config import PROCESSED_DATA_DIR
from src.feature_selection.wrapper import loco
import pandas as pd

# %%
df = pd.read_csv(PROCESSED_DATA_DIR / "dataset.csv").drop(columns=(["NDVI", "NDVI_binary", "NO2_column_number_density"]))

# %%
selected = loco(df, target_col="depr_prev", top_k=10)
print(selected)
# Out:
# LOCO: 100%|██████████| 62/62 [00:04<00:00, 13.89it/s]
# Index(['year', 'leaf_area_index_high_vegetation', 'snow_depth', 'sdi',
#        'water-permanent-coverfraction', 'pct_Single_Parent_Fam',
#        'crops-coverfraction', 'surface_latent_heat_flux_sum',
#        'pctHH_Renter_Occupied', 'shrub-coverfraction'],
#       dtype='object')
